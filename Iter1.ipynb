# %%
#Iter1.py

#1.

ventas = {
"Enero": 15000,
"Febrero": 22000,
"Marzo": 12000,
"Abril": 17000,
"Mayo": 81000,
"Junio": 13000,
"Julio": 21000,
"Agosto": 41200,
"Septiembre": 25000,
"Octubre": 21500,
"Noviembre": 91000,
"Diciembre": 21000,
}

for k,v in ventas.items():
    if v > 45000:
        print(v)
    else:
        pass
# Out:
# 81000
# 91000

# %%
#2.

for k,v in ventas.items():
    if v > 45000:
        print(k)
    else:
        pass
# Out:
# Mayo
# Noviembre
